# %%
import numpy as np
import matplotlib.pyplot as plt
import kernel
import metric

# 2. ランダムシードの固定（再現性のため）
np.random.seed(42)
n_samples=100
dim=500

# %%
t = np.linspace(0, 1, dim)

# %%
# 1. パラメータの設定
# 平均ベクトル (Mean vector)
mean = 0
# 共分散行列 (Covariance matrix)
# [[分散X, 共分散], [共分散, 分散Y]]
# ここではXとYに強い正の相関(0.8)を持たせています
cov_brownian = kernel.brownian(t)
cov_gaussian = kernel.gaussian(t)
cov_bridge = kernel.bridge(t)
